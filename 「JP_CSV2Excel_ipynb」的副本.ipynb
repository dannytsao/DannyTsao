# %% [markdown]
# <a href="https://colab.research.google.com/github/dannytsao/DannyTsao/blob/master/%E3%80%8CJP_CSV2Excel_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from google.colab import drive

import sys

# Mount Google Drive
drive.mount('/content/drive')

# Authenticate with Google Drive
drive_path = '/content/drive/MyDrive'

# Authenticate with Google Sheets
scope = ['https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/spreadsheets']

credentials = ServiceAccountCredentials.from_json_keyfile_name('/content/drive/MyDrive/JJVC_WIP/jjvc-392508-765246081d65.json', scope)
gc = gspread.authorize(credentials)


# Open the Google Sheets file
sheet = gc.open('JJVC_OTM')
worksheet = sheet.get_worksheet(0)

# Read data from the Google Sheets file
data = worksheet.get_all_values()
df_csv = pd.DataFrame(data[1:], columns=data[0])

def copy_csv_to_excel(csv_file, excel_file):
    try:
        # Create a new Excel writer object
        writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')

        # Write the DataFrame to the Excel file
        df_excel.to_csv(writer, index=False, sheet_name='ORDER')

        # Set default values in the respective columns
        default_values = {
            'OR_COUNTRY': 'TWN',
            'OR_PRINCIPAL': 'JNJ',
            'OR_TRANSACTIONCODE': 'U',
            'OR_ORDERTYPE': 'OB',
            'OR_ORDERSUBTYPE': 'DL',
            'OR_ORDERSTATUS': '9',
            'OR_TRPMODEPROFILE': 'LAND',
            'OR_TRANSPORTMODE': 'LTL',
            'OR_ORDERPRIORITY': '5',
            'OR_ORDERSOURCE': 'EXL',
            'OR_SERVICELEVEL': 'NORMAL',
            'ORIG_LOCATIONKEY': 'DTDC',
            'IP_ORDEROWNER': 'JNJ',
            'IP_OPC': 'OPC-TW',
            'ORL_LINENO': '1',
            'ORL_COMMODITY': 'GENERAL',
            'ORL_PCSQTY': 1,
            'ORL_QTYUOM': 'PCS',
            'SU_HANDLINGUNITID': 'FULL',
            'SU_TOTALOUTER': 1,
            'SU_GROSSVOLUME': 1,
            'SU_VOLUMEUOM': 'MU2',
            'SU_GROSSWEIGHT': 1,
            'SU_WEIGHTUOM': 'KG',
            'SU_ERU': 0.02,
            'SU_ERUUOM': 'PALLET',
            'SU_UPDATE': 'FROM_SOURCE'
        }

        # Copy data from CSV to Excel
        df_excel = pd.read_excel(excel_file, sheet_name='ORDER')
        df_excel['OR_CLIENTREFERENCENO'] = csv_file['Delivery']
        df_excel['OR_ORDERSOURCEID'] = csv_file['Delivery']
        df_excel['DST_LOCATIONNAME'] = csv_file['Ship-to party']
        df_excel['DST_CONTACTNO'] = csv_file['Telephone']
        df_excel['DST_ADDRESS1'] = csv_file['Street']
        df_excel['ORL_PCSQTY'] = csv_file['nit']
        df_excel['OR_ORDERADDDATE'] = csv_file['Created on']
        df_excel['OR_ORDERADDDATE'] = pd.to_datetime(df_excel['OR_ORDERADDDATE'])
        df_excel['OR_REQDELIVERYDATE'] = df_excel['OR_ORDERADDDATE'] + pd.DateOffset(days=1)

        for column, default_value in default_values.items():
            df_excel[column] = default_value

        # Save the modified Excel file
        df_excel.to_excel(writer, index=False, sheet_name='ORDER')

        writer.save()
        writer.close()

        print(f"Data copied from Google Sheets to {excel_file} successfully.")

    except Exception as e:
        print("An error occurred:", e)
        sys.exit(1)

# Define file paths
csv_file_path = drive_path + '/JJVC_WIP/JJVC_OTM.gsheet'
excel_file_path = drive_path + '/JJVC_WIP/ORDER_TEMPLATE_JNJ.gsheet'
output_excel_file_path = drive_path + '/JJVC_WIP/ORDER_WIP.gsheet'

# Copy data from CSV to Excel and set default value in 'OR_COUNTRY' column
copy_csv_to_excel(df_csv, output_excel_file_path)

#print(f"Data copied from {csv_file_path} to {output_excel_file_path} successfully.")
print(f"Data copied from Google Sheets to {excel_file} successfully.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# An error occurred: Invalid extension for engine '<property object at 0x7eff0cff6a20>': 'gsheet'
# Traceback (most recent call last):
#   File "<ipython-input-1-a54064296a4b>", line 32, in copy_csv_to_excel
#     writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/excel/_xlsxwriter.py", line 205, in __init__
#     super().__init__(
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py", line 1299, in __init__
#     self.check_extension(ext)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py", line 1467, in check_extension
#     raise ValueError(f"Invalid extension for engine '{cls.engine}': '{ext}'")
# ValueError: Invalid extension for engine '<property object at 0x7eff0cff6a20>': 'gsheet'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-a54064296a4b>", line 101, in <cell line: 101>
#     copy_csv_to_excel(df_csv, output_excel_file_path)
#   File "<ipython-input-1-a54064296a4b>", line 93, in copy_csv_to_excel
#     sys.exit(1)
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-a54064296a4b> in copy_csv_to_excel(csv_file, excel_file)
#      31         # Create a new Excel writer object
# ---> 32         writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')
#      33
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     204
# --> 205         super().__init__(
#     206             path,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1298             ext = os.path.splitext(path)[-1]
# -> 1299             self.check_extension(ext)
#    1300
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in check_extension(cls, ext)
#    1466         if not any(ext in extension for extension in cls._supported_extensions):
# -> 1467             raise ValueError(f"Invalid extension for engine '{cls.engine}': '{ext}'")
#    1468         else:
#
# ValueError: Invalid extension for engine '<property object at 0x7eff0cff6a20>': 'gsheet'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-1-a54064296a4b> in <cell line: 101>()
#     100 # Copy data from CSV to Excel and set default value in 'OR_COUNTRY' column
# --> 101 copy_csv_to_excel(df_csv, output_excel_file_path)
#     102
#
# <ipython-input-1-a54064296a4b> in copy_csv_to_excel(csv_file, excel_file)
#      92         print("An error occurred:", e)
# ---> 93         sys.exit(1)
#      94
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2090                     stb = ['An exception has occurred, use %tb to see '
#    2091                            'the full traceback.\n']
# -> 2092                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2093                                                                      value))
#    2094                 else:
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     627             chained_exceptions_tb_offset = 0
#     628             out_list = (
# --> 629                 self.structured_traceback(
#     630                     etype, evalue, (etb, chained_exc_ids),
#     631                     chained_exceptions_tb_offset, context)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
